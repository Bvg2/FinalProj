# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

water = pd.read_csv("water.csv")

# %%
water.head(10)
# Out:
#                            id                                  name  \
# neighborhood
# Beechview          1816791851                        Able Long Park
# Crawford-Roberts   1599892422               Albert Turk Graham Park
# Allegheny Center   1422043278             Allegheny Commons Arch St
# Allegheny Center   1237191582  Allegheny Commons East Tennis Courts
# Allegheny Center   1146184773                Allegheny Commons Pool
# Beechview          1230448600                            Alton Park
# Bedford Dwellings   887743707                   Ammon Park Building
# Bedford Dwellings  1767127832                      Ammon Park Spray
# South Side Flats    354464900                        Armstrong Park
# South Side Flats    495479912                  Armstrong Park Spray
#
#                   control_type       feature_type inactive              make  \
# neighborhood
# Beechview           Continuous  Drinking Fountain        f  Regular Fountain
# ...

# %%
water.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     225 non-null    int64
#  1   name                   225 non-null    object
#  2   control_type           196 non-null    object
#  3   feature_type           225 non-null    object
#  4   inactive               185 non-null    object
#  5   make                   158 non-null    object
#  6   image                  196 non-null    object
#  7   neighborhood           225 non-null    object
#  8   council_district       225 non-null    int64
#  9   ward                   225 non-null    int64
#  10  tract                  225 non-null    int64
#  11  public_works_division  225 non-null    int64
#  12  pli_division           225 non-null    int64
#  13  police_zone            225 non-null    int64
# ...

# %%
len(water)
# Out:
# 225

# %%
water = pd.read_csv("water.csv", index_col="neighborhood", parse_dates=True)
water.head(225)
# Out:
#                              id                                      name  \
# neighborhood
# Beechview            1816791851                            Able Long Park
# Crawford-Roberts     1599892422                   Albert Turk Graham Park
# Allegheny Center     1422043278                 Allegheny Commons Arch St
# Allegheny Center     1237191582      Allegheny Commons East Tennis Courts
# Allegheny Center     1146184773                    Allegheny Commons Pool
# ...                         ...                                       ...
# Garfield             1646811568  Nelson Mandela Peace Park Spray Fountain
# Point Breeze North   1127368170                         Westinghouse Park
# East Liberty         1861451108                        Liberty Green Park
# Squirrel Hill North  1019085573                             Wightman Park
# Highland Park         250376003                 Highland Park Reservoir 2
#
#                     control_type       feature_type inactive  \
# ...

# %%
water.plot()

# %%
water.groupby('neighborhood').count()
# Out:
#                      id  name  control_type  feature_type  inactive  make  \
# neighborhood
# Allegheny Center      6     6             5             6         3     4
# Allentown             2     2             2             2         2     2
# Banksville            3     3             3             3         2     2
# Bedford Dwellings     3     3             2             3         2     1
# Beechview             5     5             5             5         5     5
# ...                  ..   ...           ...           ...       ...   ...
# Upper Hill            2     2             2             2         1     1
# Upper Lawrenceville   1     1             1             1         1     1
# West End              2     2             1             2         2     1
# Westwood              2     2             2             2         2     2
# Windgap               2     2             1             2         2     1
#
#                      image  council_district  ward  tract  \
# ...
