# %% [markdown]
# # Best Neighborhood in Pittsburgh for Dogs (Giovanna's Part)

# %% [markdown]
# ![alt text](https://media.giphy.com/media/fIrbAgjX4Gjqo/giphy-downsized-large.gif)

# %% [markdown]
# ## Dogs like friends! Which neighborhoods have the most dog friends?

# %%
import pandas as pd

# %matplotlib inline

# %% [markdown]
# 311 is the non-emergency helpline in Pittsburgh. There were previously 500,000 rows of complaints.

# %%
#filters out all requests besides "Barking Dog"
data = pd.read_csv("311.csv", index_col="NEIGHBORHOOD", parse_dates=True)
dogStuff = data[data.REQUEST_TYPE == "Barking Dog"]
dogStuff.head(10)
# Out:
#                   REQUEST_ID           CREATED_ON REQUEST_TYPE REQUEST_ORIGIN  \
# NEIGHBORHOOD
# Brighton Heights     32256.0  2015-11-06T14:57:00  Barking Dog    Call Center
# Brookline            32217.0  2015-11-06T12:57:00  Barking Dog    Call Center
# Mount Washington     30619.0  2015-11-03T18:05:00  Barking Dog        Website
# Morningside          30109.0  2015-10-30T17:08:00  Barking Dog    Call Center
# Crafton Heights      30090.0  2015-10-30T15:59:00  Barking Dog        Website
# Mount Washington     30051.0  2015-10-30T13:42:00  Barking Dog    Call Center
# Elliott              30617.0  2015-11-03T17:38:00  Barking Dog    Call Center
# Windgap             203008.0  2017-12-13T20:57:00  Barking Dog        Website
# Westwood            202609.0  2017-12-11T19:13:00  Barking Dog        Website
# Brookline           202386.0  2017-12-09T20:15:00  Barking Dog        Website
#
#                   STATUS             DEPARTMENT  COUNCIL_DISTRICT  WARD  \
# NEIGHBORHOOD
# Brighton Heights     1.0  Animal Care & Control               1.0  27.0
# Brookline            1.0  Animal Care & Control               4.0  19.0
# Mount Washington     1.0  Animal Care & Control               3.0  18.0
# Morningside          1.0  Animal Care & Control               7.0  10.0
# Crafton Heights      1.0  Animal Care & Control               2.0  28.0
# Mount Washington     1.0  Animal Care & Control               3.0  18.0
# Elliott              1.0  Animal Care & Control               2.0  20.0
# Windgap              1.0  Animal Care & Control               2.0  28.0
# Westwood             1.0  Animal Care & Control               2.0  20.0
# Brookline            1.0  Animal Care & Control               4.0  19.0
#
#                          TRACT  PUBLIC_WORKS_DIVISION  PLI_DIVISION  \
# NEIGHBORHOOD
# Brighton Heights  4.200327e+10                    1.0          27.0
# Brookline         4.200319e+10                    5.0          19.0
# Mount Washington  4.200318e+10                    5.0          18.0
# Morningside       4.200310e+10                    2.0          10.0
# Crafton Heights   4.200328e+10                    5.0          28.0
# Mount Washington  4.200318e+10                    5.0          18.0
# Elliott           4.200356e+10                    5.0          20.0
# Windgap           4.200356e+10                    5.0          28.0
# Westwood          4.200356e+10                    5.0          20.0
# Brookline         4.200319e+10                    5.0          19.0
#
#                   POLICE_ZONE FIRE_ZONE          X          Y GEO_ACCURACY
# NEIGHBORHOOD
# Brighton Heights          1.0      1-14 -80.029414  40.480043  APPROXIMATE
# Brookline                 6.0      4-26 -80.019153  40.394317  APPROXIMATE
# Mount Washington          3.0       4-5 -80.000728  40.426637  APPROXIMATE
# Morningside               5.0       3-7 -79.923948  40.486686  APPROXIMATE
# Crafton Heights           6.0      1-17 -80.049404  40.440520  APPROXIMATE
# Mount Washington          3.0       4-5 -80.000428  40.424557  APPROXIMATE
# Elliott                   6.0      1-17 -80.041106  40.439968  APPROXIMATE
# Windgap                   6.0      1-16 -80.078004  40.460014  APPROXIMATE
# Westwood                  6.0      1-18 -80.042378  40.434077  APPROXIMATE
# Brookline                 6.0      4-26 -80.012244  40.390187  APPROXIMATE

# %%
dogStuff.groupby("NEIGHBORHOOD").count()
# Out:
#                      REQUEST_ID  CREATED_ON  REQUEST_TYPE  REQUEST_ORIGIN  \
# NEIGHBORHOOD
# Allegheny West                5           5             5               5
# Allentown                    11          11            11              11
# Arlington                     9           9             9               9
# Banksville                   21          21            21              21
# Beechview                    31          31            31              31
# ...                         ...         ...           ...             ...
# Upper Hill                    2           2             2               2
# Upper Lawrenceville           7           7             7               7
# West Oakland                  5           5             5               5
# Westwood                      8           8             8               8
# Windgap                       9           9             9               9
#
#                      STATUS  DEPARTMENT  COUNCIL_DISTRICT  WARD  TRACT  \
# NEIGHBORHOOD
# Allegheny West            5           5                 5     5      5
# Allentown                11          11                11    11     11
# Arlington                 9           9                 9     9      9
# Banksville               21          21                21    21     21
# Beechview                31          31                31    31     31
# ...                     ...         ...               ...   ...    ...
# Upper Hill                2           2                 2     2      2
# Upper Lawrenceville       7           7                 7     7      7
# West Oakland              5           5                 5     5      5
# Westwood                  8           8                 8     8      8
# Windgap                   9           9                 9     9      9
#
#                      PUBLIC_WORKS_DIVISION  PLI_DIVISION  POLICE_ZONE  \
# NEIGHBORHOOD
# Allegheny West                           5             5            5
# Allentown                               11            11           11
# Arlington                                9             9            9
# Banksville                              21            21           21
# Beechview                               31            31           31
# ...                                    ...           ...          ...
# Upper Hill                               2             2            2
# Upper Lawrenceville                      7             7            7
# West Oakland                             5             5            5
# Westwood                                 8             8            8
# Windgap                                  9             9            9
#
#                      FIRE_ZONE   X   Y  GEO_ACCURACY
# NEIGHBORHOOD
# Allegheny West               5   5   5             5
# Allentown                   11  11  11            11
# Arlington                    9   9   9             9
# Banksville                  21  21  21            21
# Beechview                   31  31  31            31
# ...                        ...  ..  ..           ...
# Upper Hill                   2   2   2             2
# Upper Lawrenceville          7   7   7             7
# West Oakland                 5   5   5             5
# Westwood                     8   8   8             8
# Windgap                      9   9   9             9
#
# [69 rows x 16 columns]

# %%
dogStuff.groupby(['NEIGHBORHOOD','REQUEST_TYPE']).size().sort_values(ascending=False)
# Out:
# NEIGHBORHOOD      REQUEST_TYPE
# Brookline         Barking Dog     68
# Mount Washington  Barking Dog     51
# Carrick           Barking Dog     46
# Brighton Heights  Barking Dog     31
# Beechview         Barking Dog     31
#                                   ..
# Strip District    Barking Dog      1
# Homewood South    Barking Dog      1
# Chateau           Barking Dog      1
# Hays              Barking Dog      1
# Larimer           Barking Dog      1
# Length: 69, dtype: int64

# %%
#this code removes neighborhoods with less than 10 complaints
def filter_by_barks (x, threshold):
    if len(x) > threshold:
        return True
    else: 
        return False

dog_friends = dogStuff.groupby("NEIGHBORHOOD").filter(filter_by_barks, 
                                                      threshold=10)

dog_friends.groupby("NEIGHBORHOOD").count()
# Out:
#                        REQUEST_ID  CREATED_ON  REQUEST_TYPE  REQUEST_ORIGIN  \
# NEIGHBORHOOD
# Allentown                      11          11            11              11
# Banksville                     21          21            21              21
# Beechview                      31          31            31              31
# Bloomfield                     18          18            18              18
# Brighton Heights               31          31            31              31
# Brookline                      68          68            68              68
# Carrick                        46          46            46              46
# Central Lawrenceville          15          15            15              15
# Crafton Heights                11          11            11              11
# Duquesne Heights               11          11            11              11
# East Liberty                   15          15            15              15
# Elliott                        11          11            11              11
# Garfield                       12          12            12              12
# Greenfield                     27          27            27              27
# Highland Park                  27          27            27              27
# Knoxville                      16          16            16              16
# Marshall-Shadeland             23          23            23              23
# Morningside                    16          16            16              16
# Mount Washington               51          51            51              51
# Overbrook                      17          17            17              17
# Perry North                    17          17            17              17
# Perry South                    20          20            20              20
# Polish Hill                    11          11            11              11
# Sheraden                       21          21            21              21
# South Side Slopes              11          11            11              11
# Squirrel Hill North            14          14            14              14
# Squirrel Hill South            15          15            15              15
# Stanton Heights                15          15            15              15
# Troy Hill                      25          25            25              25
#
#                        STATUS  DEPARTMENT  COUNCIL_DISTRICT  WARD  TRACT  \
# NEIGHBORHOOD
# Allentown                  11          11                11    11     11
# Banksville                 21          21                21    21     21
# Beechview                  31          31                31    31     31
# Bloomfield                 18          18                18    18     18
# Brighton Heights           31          31                31    31     31
# Brookline                  68          68                68    68     68
# Carrick                    46          46                46    46     46
# Central Lawrenceville      15          15                15    15     15
# Crafton Heights            11          11                11    11     11
# Duquesne Heights           11          11                11    11     11
# East Liberty               15          15                15    15     15
# Elliott                    11          11                11    11     11
# Garfield                   12          12                12    12     12
# Greenfield                 27          27                27    27     27
# Highland Park              27          27                27    27     27
# Knoxville                  16          16                16    16     16
# Marshall-Shadeland         23          23                23    23     23
# Morningside                16          16                16    16     16
# Mount Washington           51          51                51    51     51
# Overbrook                  17          17                17    17     17
# Perry North                17          17                17    17     17
# Perry South                20          20                20    20     20
# Polish Hill                11          11                11    11     11
# Sheraden                   21          21                21    21     21
# South Side Slopes          11          11                11    11     11
# Squirrel Hill North        14          14                14    14     14
# Squirrel Hill South        15          15                15    15     15
# Stanton Heights            15          15                15    15     15
# Troy Hill                  25          25                25    25     25
#
#                        PUBLIC_WORKS_DIVISION  PLI_DIVISION  POLICE_ZONE  \
# NEIGHBORHOOD
# Allentown                                 11            11           11
# Banksville                                21            21           21
# Beechview                                 31            31           31
# Bloomfield                                18            18           18
# Brighton Heights                          31            31           31
# Brookline                                 68            68           68
# Carrick                                   46            46           46
# Central Lawrenceville                     15            15           15
# Crafton Heights                           11            11           11
# Duquesne Heights                          11            11           11
# East Liberty                              15            15           15
# Elliott                                   11            11           11
# Garfield                                  12            12           12
# Greenfield                                27            27           27
# Highland Park                             27            27           27
# Knoxville                                 16            16           16
# Marshall-Shadeland                        23            23           23
# Morningside                               16            16           16
# Mount Washington                          51            51           51
# Overbrook                                 17            17           17
# Perry North                               17            17           17
# Perry South                               20            20           20
# Polish Hill                               11            11           11
# Sheraden                                  21            21           21
# South Side Slopes                         11            11           11
# Squirrel Hill North                       14            14           14
# Squirrel Hill South                       15            15           15
# Stanton Heights                           15            15           15
# Troy Hill                                 25            25           25
#
#                        FIRE_ZONE   X   Y  GEO_ACCURACY
# NEIGHBORHOOD
# Allentown                     11  11  11            11
# Banksville                    21  21  21            21
# Beechview                     31  31  31            31
# Bloomfield                    18  18  18            18
# Brighton Heights              31  31  31            31
# Brookline                     68  68  68            68
# Carrick                       46  46  46            46
# Central Lawrenceville         15  15  15            15
# Crafton Heights               11  11  11            11
# Duquesne Heights              11  11  11            11
# East Liberty                  15  15  15            15
# Elliott                       11  11  11            11
# Garfield                      12  12  12            12
# Greenfield                    27  27  27            27
# Highland Park                 27  27  27            27
# Knoxville                     16  16  16            16
# Marshall-Shadeland            23  23  23            23
# Morningside                   16  16  16            16
# Mount Washington              51  51  51            51
# Overbrook                     17  17  17            17
# Perry North                   17  17  17            17
# Perry South                   20  20  20            20
# Polish Hill                   11  11  11            11
# Sheraden                      21  21  21            21
# South Side Slopes             11  11  11            11
# Squirrel Hill North           14  14  14            14
# Squirrel Hill South           15  15  15            15
# Stanton Heights               15  15  15            15
# Troy Hill                     25  25  25            25

# %%
dogFriends = dog_friends.groupby(['NEIGHBORHOOD']).size().sort_values(ascending=False)
dogFriends.head(25)
# Out:
# NEIGHBORHOOD
# Brookline                68
# Mount Washington         51
# Carrick                  46
# Beechview                31
# Brighton Heights         31
# Highland Park            27
# Greenfield               27
# Troy Hill                25
# Marshall-Shadeland       23
# Banksville               21
# Sheraden                 21
# Perry South              20
# Bloomfield               18
# Perry North              17
# Overbrook                17
# Morningside              16
# Knoxville                16
# Central Lawrenceville    15
# Squirrel Hill South      15
# East Liberty             15
# Stanton Heights          15
# Squirrel Hill North      14
# Garfield                 12
# Crafton Heights          11
# Duquesne Heights         11
# dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.style.use('seaborn-pastel')
dogFriends.plot.barh(title = 'Barking Dogs in PGH', x= 'Neighborhood', y='Barking Dogs', figsize=(12,12)).invert_yaxis()

# %%
#Now a pie chart
plt.style.use('seaborn-pastel')
dogFriends.plot.pie(figsize = (12,12), title= 'Barking Dogs in PGH')

# %% [markdown]
# # Conclusion
# We discovered that Brookline is the neighborhood with the most barking dogs. However, this not the only metric that we took into consideration.
