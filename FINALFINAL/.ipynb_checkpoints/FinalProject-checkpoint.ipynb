# %% [markdown]
# # Best Neighborhood for a dog in pittsburgh (Bens part)
# ## By Park Area:

# %% [markdown]
# # DOGS LIKE PARKS!!!!
# ### What neighborhood has the access to the most park area!!!
#
#
# ![dog](https://media.giphy.com/media/ZNegC7wFpuQT7nurZ0/giphy.gif)

# %%
# import step
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import geopandas
import random

# %%
#reading in my dataframe to make this dataset I used arcgis
#to split the neighborood csv by the park csv based on whether there was overlap
data = pd.read_csv("realData.csv")

#taking in the real data then cutting down the data set into important values
#then sorting them based on the park area 
data1 = data[['HOOD','Shape_Area', 'updatepknm','Shape__Are']]
shapeData = data1.sort_values(by='Shape_Area',ascending=False)
df = shapeData[['Shape__Are', 'HOOD', 'Shape_Area','updatepknm']]


#this is the part where everything is added together if it has the same hood name
aggregation_functions = {'Shape__Are': 'sum', 'Shape_Area': 'sum','HOOD': 'first','updatepknm': 'sum'}

df_new = df.groupby(df['HOOD']).aggregate(aggregation_functions)
df_new = df_new.sort_values(by='Shape__Are',ascending=False)
df_new = df_new[['HOOD', 'updatepknm','Shape__Are']]


#this is the graphing part
df_new[0:20].plot(kind='barh',rot = 0, figsize=(12,12), title="Total Park area by neighborhood").invert_yaxis()
plt.style.use('seaborn-pastel')
df_new[0:10].plot.pie(y='Shape__Are', figsize=(12,12), fontsize=20, title="Total Park area by neighborhood (pieChart)")


plt.show()

# %% [markdown]
# ### Above is a bar graph and a pie chart representing the area of parks by neighborhood, squirrel hill south is shown to have

# %% [markdown]
# ### This is a list of the neighborhood

# %%
df_new = df_new[['updatepknm','Shape__Are']]
df_new.head(30)
# Out:
#                                                                   updatepknm  \
# HOOD
# Squirrel Hill South        Frick ParkSchenley ParkDavis ParkFour Mile Run...
# Point Breeze               Frick ParkMellon ParkMellon Park IslandSterret...
# Swisshelm Park             Frick ParkSwisshelm ParkWindermere Circle 1 & ...
# Regent Square                           Frick ParkRegent Square War Memorial
# Greenfield                 Magee ParkSchenley ParkFour Mile Run ParkSalin...
# South Oakland              Schenley ParkFrazier ParkLawn and Ophelia Park...
# Squirrel Hill North                               Schenley ParkWightman Park
# Central Oakland            Schenley ParkZulema ParkOakland SquareBoundary...
# North Oakland                                   Schenley ParkHarris Triangle
# Lincoln-Lemington-Belmar   Highland ParkChadwick ParkPaulson ParkPaulson ...
# Morningside                          Highland ParkJoe Natoli ParkHeth's Park
# Highland Park                                       Highland ParkHeth's Park
# Marshall-Shadeland         Young Field ParkWashburn Square ParkWoods Run ...
# Perry North                                        Riverview ParkGarvin Park
# Mount Washington           Emerald View Regional ParkEmerald View Park - ...
# Duquesne Heights           Emerald View Park - Duquesne Heights GreenwayE...
# Allentown                  Emerald View Park - Grandview ParkEmerald View...
# South Shore                                       Emerald View Regional Park
# West End                   West End ParkWabash ParkWest End Healthy Activ...
# Beltzhoover                          McKinley ParkWarrington ParkVenson Park
# Overbrook                               Brookline Memorial ParkPhillips Park
# Bon Air                                            McKinley ParkBon Air Park
# Knoxville                                                      McKinley Park
# South Side Slopes          Southside ParkMonongahela ParkArlington ParkWi...
# Brookline                  Brookline Memorial ParkMoore ParkBrookline Mon...
# Allegheny Center           Allegheny CommonsBuhl Community Park at Allegh...
# Allegheny West                                             Allegheny Commons
# Sheraden                   Sheraden ParkMcGonigle ParkTuxedo Street Skate...
# Central Business District  Point State ParkFrankie Pace ParkFort Duquesne...
# Brighton Heights           Brighton Heights ParkMarmaduke ParkBrighton He...
#
#                              Shape__Are
# HOOD
# Squirrel Hill South        7.220538e+06
# Point Breeze               4.393606e+06
# Swisshelm Park             4.166232e+06
# Regent Square              4.157575e+06
# Greenfield                 3.094934e+06
# South Oakland              3.066373e+06
# Squirrel Hill North        3.051154e+06
# Central Oakland            3.048607e+06
# North Oakland              3.037520e+06
# Lincoln-Lemington-Belmar   2.722724e+06
# Morningside                2.720142e+06
# Highland Park              2.682229e+06
# Marshall-Shadeland         1.835905e+06
# Perry North                1.822231e+06
# Mount Washington           1.449233e+06
# Duquesne Heights           1.273866e+06
# Allentown                  1.012227e+06
# South Shore                7.727741e+05
# West End                   5.699411e+05
# Beltzhoover                5.601633e+05
# Overbrook                  5.527831e+05
# Bon Air                    5.494035e+05
# Knoxville                  5.439568e+05
# South Side Slopes          4.980451e+05
# Brookline                  4.628054e+05
# Allegheny Center           4.471942e+05
# Allegheny West             4.295252e+05
# Sheraden                   4.103075e+05
# Central Business District  2.827183e+05
# Brighton Heights           2.467557e+05

# %% [markdown]
# ### this is a test to confirm that the addition of each neighborhood works
# This adds the data in a different way, as you can see it matches the data above. meaning that the addition method I did probably worked as intended

# %%
data = pd.read_csv("realData.csv")

data1 = data[['HOOD','Shape_Area', 'updatepknm','Shape__Are']]
data1 = data1.sort_values(by='HOOD')
shapeData = data1.sort_values(by='Shape_Area',ascending=False)

sqs = shapeData[shapeData.HOOD == "Squirrel Hill South"]
sqs = sqs[["Shape__Are"]]
sqSum = sqs.sum()
print(sqSum, "sq of total park in squirrel hill south")

#npNumbers = data[data.Park_Name == "North Park"]
# Out:
# Shape__Are    7.220538e+06
# dtype: float64 sq of total park in squirrel hill south

# %% [markdown]
# # The Data from above shows that the top Three neighborhoods with the most parks are:
# ## #1)Squirrel hill south
# ### #2)Point Breeze
# #### #3)Swisshelmpark

# %%
neighborhoods = geopandas.read_file("Neighborhoods/Neighborhoods_.shp") # read in the shapefile

# %%
df_map = neighborhoods.merge(df_new, how='left', left_on='hood', right_on='HOOD')
df_map.head()
df_map.plot(column='Shape__Are_y',# set the data to be used for coloring
               cmap='BuGn',              # choose a color palette
               edgecolor="white",        # outline the districts in white
               legend=True,              # show the legend
               legend_kwds={'label': "ParkSize"}, # label the legend
               figsize=(15, 10),         # set the size # set disctricts with no data to gray
               )
